# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import numpy as np
import pandas as pd

# %%
data_frame = pd.read_csv("summer.csv")

# %%
data_frame.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
city = []
for cities in data_frame['City'].unique():
    city.append(cities)
len(city)
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
sport_most_gold_medals = []
for sport in data_frame2['Sport'].unique():
    sport_most_gold_medals.append([sport , len(data_frame2[data_frame2['Sport']  == sport])])
sport_most_gold_medals = pd.DataFrame(sport_most_gold_medals)
sport_most_gold_medals.rename(columns = {0:'Sport',1:'No of gold medals'},inplace = True)
sport_most_gold_medals = sport_most_gold_medals.sort_values(by ='No of gold medals',ascending = False).head()
sport_most_gold_medals.plot(x='Sport',y = 'No of gold medals',kind = 'bar')
sport_most_gold_medals
# Out:
#          Sport  No of gold medals
# 0     Aquatics               1421
# 1    Athletics               1215
# 17      Rowing                890
# 4   Gymnastics                820
# 3      Fencing                552

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
sport_most_medals = []
for sport in data_frame['Sport'].unique():
    sport_most_medals.append([sport , len(data_frame[data_frame['Sport']  == sport])])
sport_most_medals = pd.DataFrame(sport_most_medals)
sport_most_medals.rename(columns = {0:'Sport',1:'No of medals'},inplace = True)
sport_most_medals = sport_most_medals.sort_values(by ='No of medals',ascending = False).head()
sport_most_medals.plot(x='Sport',y = 'No of medals',kind = 'bar')
sport_most_medals
# Out:
#          Sport  No of medals
# 0     Aquatics          4170
# 1    Athletics          3638
# 17      Rowing          2667
# 4   Gymnastics          2307
# 3      Fencing          1613

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
Most_medals = []
for athlete in data_frame['Athlete'].unique():
    Most_medals.append([athlete , len(data_frame[data_frame['Athlete']  == athlete])])
Most_medals = pd.DataFrame(Most_medals)
Most_medals.rename(columns = {0:'Athlete',1:'No of medals'},inplace = True)
Most_medals = Most_medals.sort_values(by = 'No of medals',ascending = False).head()
Most_medals.plot(x='Athlete',y = 'No of medals',kind = 'bar')
Most_medals
# Out:
#                     Athlete  No of medals
# 18640       PHELPS, Michael            22
# 7197       LATYNINA, Larisa            18
# 9948     ANDRIANOV, Nikolay            15
# 6591           ONO, Takashi            13
# 5103   MANGIAROTTI, Edoardo            13

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
data_frame2 = data_frame[data_frame['Medal'] == "Gold"]
data_frame2
Most_medals = []
for athlete in data_frame2['Athlete'].unique():
    Most_medals.append([athlete , len(data_frame2[data_frame2['Athlete']  == athlete])])
Most_medals = pd.DataFrame(Most_medals)
Most_medals.rename(columns = {0:'Athlete',1:'No of gold medals'},inplace = True)
Most_medals = Most_medals.sort_values(by = 'No of gold medals',ascending = False).head()
Most_medals.plot(x='Athlete',y = 'No of gold medals',kind = 'bar')
Most_medals
# Out:
#                Athlete  No of gold medals
# 6851   PHELPS, Michael                 18
# 3320       SPITZ, Mark                  9
# 2714  LATYNINA, Larisa                  9
# 4630       LEWIS, Carl                  9
# 907       NURMI, Paavo                  9

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
data_frame1 = data_frame[(data_frame['Medal'] == 'Gold') & (data_frame['Country'] == 'IND')]
min(data_frame1['Year'])
data_frame1
# Out:
#        Year         City     Sport Discipline                       Athlete  \
# 5512   1928    Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928    Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928    Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928    Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928    Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# 5517   1928    Amsterdam    Hockey     Hockey       HAMMOND, Leslie Charles
# 5518   1928    Amsterdam    Hockey     Hockey            KHAN, Feroze Uddin
# 5519   1928    Amsterdam    Hockey     Hockey           MARTHINS, George E.
# 5520   1928    Amsterdam    Hockey     Hockey                NORRIS, Rex A.
# 5521   1928    Amsterdam    Hockey     Hockey         PINNIGER, Broome Eric
# 5522   1928    Amsterdam    Hockey     Hockey            ROCQUE, Michael E.
# ...

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
events_df = []
for event in data_frame['Event'].unique():
    events_df.append([event , len(data_frame[data_frame['Event']  == event])])
events_df = pd.DataFrame(events_df)
events_df.rename(columns = {0:'Event',1:'No of players'},inplace = True)
events_df = events_df.sort_values(by = 'No of players',ascending = False).head()
events_df.plot(x='Event',y = 'No of players',kind = 'bar')
events_df
# Out:
#                 Event  No of players
# 80           Football           1497
# 176            Hockey           1422
# 138  Team Competition           1147
# 327        Basketball           1012
# 337          Handball            973

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
women_athlete = data_frame[(data_frame['Gender']=='Women') & (data_frame['Medal'] == 'Gold')]
sport_medal = []
for sport in women_athlete['Sport'].unique():
    sport_medal.append([sport , len(women_athlete[womenath['Sport']  == sport])])
sport_df = pd.DataFrame(sport_medal)
sport_df1 = sport_df.sort_values(by = 1 ,ascending = False).head()
sport_df1.rename(columns = {0:'Sport',1:'No of gold medals'},inplace = True)
sport_df1.plot(kind = 'bar',x = 'Sport', y = 'No of gold medals')
sport_df1
# Out:
#          Sport  No of gold medals
# 4     Aquatics                589
# 7    Athletics                389
# 8   Gymnastics                268
# 14      Rowing                217
# 11  Volleyball                166
